# %% [markdown]
# This script converts my data into a similarity matrix

# %%
import pandas, numpy
from pandas import DataFrame
import numpy as np
import pandas as pd


#Read in sorted data 
df = pandas.read_csv('Documents/Similarity_for_MDS.csv')
df = df.drop(columns = "Unnamed: 0")


#Define what order the words will be in the Dissimilarity matrix
my_order = ['Animals_010_h.jpg', 'Animals_206_h.jpg', 'Faces_017_h.jpg', 'Faces_032_h.jpg', 'Faces_041_h.jpg', 'Faces_134_h.jpg', 'Faces_270_h.jpg', 'Faces_315_h.jpg', 'Landscapes_026_h.jpg', 'Landscapes_132_h.jpg', 'Objects_145_h.jpg', 'People_067_h.jpg', 'People_075_v.jpg', 'People_127_h.jpg', 'People_143_h.jpg']


n = len(my_order)

## pre-allocate Representational Dissimilarity Matrix
rdm = numpy.zeros([n, n])

#Set parameters
num_trials = 105

#Set participants
participants = df.Participant_ID
#Note that using this code will give us the list of participants in the order they appear rather than sorted
indexes = np.unique(participants, return_index=True)[1]
participants = [participants[index] for index in sorted (indexes)]
num_participants = len(participants)
data = ([])

for ppt in range(1, num_participants+1):
        EC_data_sorted_new = df[((ppt*num_trials)-num_trials):(num_trials*ppt)]
        for _, row in EC_data_sorted_new.iterrows():
            i1 = my_order.index(row.Image_1)
            i2 = my_order.index(row.Image_2)
            rdm[i1, i2] = row.Rating
            ## the RDM is symmetrical about the diagonal
            rdm[i2, i1] = row.Rating
            #Now save a rdm for each participant to a cell array
        data.append(rdm)
        rdm = numpy.zeros([n, n])

#Data for all participants
data = numpy.array(data)


#Make array for each participant 
ppt1_dist = data[0:1, 0:15,]
ppt1_dist = ppt1_dist.reshape(15,15)
ppt2_dist = data[1:2, :15,]
ppt2_dist =ppt2_dist.reshape(15,15)
ppt3_dist = data[2:3, :15,]
ppt3_dist =ppt3_dist.reshape(15,15)
ppt4_dist = data[3:4, :15,]
ppt4_dist =ppt4_dist.reshape(15,15)
ppt5_dist = data[4:5, :15,]
ppt5_dist =ppt5_dist.reshape(15,15)
ppt6_dist = data[5:6, :15,]
ppt6_dist =ppt6_dist.reshape(15,15)
ppt7_dist = data[6:7, :15,]
ppt7_dist =ppt7_dist.reshape(15,15)
ppt8_dist = data[7:8, :15,]
ppt8_dist =ppt8_dist.reshape(15,15)
ppt9_dist = data[8:9, :15,]
ppt9_dist =ppt9_dist.reshape(15,15)
ppt10_dist = data[9:10, :15,]
ppt10_dist =ppt10_dist.reshape(15,15)
ppt11_dist = data[10:11, :15,]
ppt11_dist =ppt11_dist.reshape(15,15)
ppt12_dist = data[11:12, :15,]
ppt12_dist =ppt12_dist.reshape(15,15)
ppt13_dist = data[12:13, :15,]
ppt13_dist =ppt13_dist.reshape(15,15)
ppt14_dist = data[13:14, :15,]
ppt14_dist =ppt14_dist.reshape(15,15)
ppt15_dist = data[14:15, :15,]
ppt15_dist =ppt15_dist.reshape(15,15)
ppt16_dist = data[15:16, :15,]
ppt16_dist =ppt16_dist.reshape(15,15)
ppt17_dist = data[16:17, :15,]
ppt17_dist =ppt17_dist.reshape(15,15)
ppt18_dist = data[17:18, :15,]
ppt18_dist =ppt18_dist.reshape(15,15)
ppt19_dist = data[18:19, :15,]
ppt19_dist =ppt19_dist.reshape(15,15)
ppt20_dist = data[19:20, :15,]
ppt20_dist =ppt20_dist.reshape(15,15)
ppt21_dist = data[20:21, :15,]
ppt21_dist =ppt21_dist.reshape(15,15)
ppt22_dist = data[21:22, :15,]
ppt22_dist =ppt22_dist.reshape(15,15)
ppt23_dist = data[22:23, :15,]
ppt23_dist =ppt23_dist.reshape(15,15)
ppt24_dist = data[23:24, :15,]
ppt24_dist =ppt24_dist.reshape(15,15)
ppt25_dist = data[24:25, :15,]
ppt25_dist =ppt25_dist.reshape(15,15)
ppt26_dist = data[25:26, :15,]
ppt26_dist =ppt26_dist.reshape(15,15)
ppt27_dist = data[26:27, :15,]
ppt27_dist =ppt27_dist.reshape(15,15)
ppt28_dist = data[27:28, :15,]
ppt28_dist =ppt28_dist.reshape(15,15)
ppt29_dist = data[28:29, :15,]
ppt29_dist =ppt29_dist.reshape(15,15)
ppt30_dist = data[29:30, :15,]
ppt30_dist =ppt30_dist.reshape(15,15)
ppt31_dist = data[30:31, :15,]
ppt31_dist =ppt31_dist.reshape(15,15)
ppt32_dist = data[31:32, :15,]
ppt32_dist =ppt32_dist.reshape(15,15)
ppt33_dist = data[32:33, :15,]
ppt33_dist =ppt33_dist.reshape(15,15)
ppt34_dist = data[33:34, :15,]
ppt34_dist =ppt34_dist.reshape(15,15)
ppt35_dist = data[34:35, :15,]
ppt35_dist =ppt35_dist.reshape(15,15)
ppt36_dist = data[35:36, :15,]
ppt36_dist =ppt36_dist.reshape(15,15)
ppt37_dist = data[36:37, :15,]
ppt37_dist =ppt37_dist.reshape(15,15)
ppt38_dist = data[37:38, :15,]
ppt38_dist =ppt38_dist.reshape(15,15)
ppt39_dist = data[38:39, :15,]
ppt39_dist =ppt39_dist.reshape(15,15)
ppt40_dist = data[39:40, :15,]
ppt40_dist =ppt40_dist.reshape(15,15)
ppt41_dist = data[40:41, :15,]
ppt41_dist =ppt41_dist.reshape(15,15)
ppt42_dist = data[41:42, :15,]
ppt42_dist =ppt42_dist.reshape(15,15)
ppt43_dist = data[42:43, :15,]
ppt43_dist =ppt43_dist.reshape(15,15)
ppt44_dist = data[43:44, :15,]
ppt44_dist =ppt44_dist.reshape(15,15)
ppt45_dist = data[44:45, :15,]
ppt45_dist =ppt45_dist.reshape(15,15)
ppt46_dist = data[45:46, :15,]
ppt46_dist =ppt46_dist.reshape(15,15)
ppt47_dist = data[46:47, :15,]
ppt47_dist =ppt47_dist.reshape(15,15)
ppt48_dist = data[47:48, :15,]
ppt48_dist =ppt48_dist.reshape(15,15)
ppt49_dist = data[48:49, :15,]
ppt49_dist =ppt49_dist.reshape(15,15)
ppt50_dist = data[49:50, :15,]
ppt50_dist =ppt50_dist.reshape(15,15)
ppt51_dist = data[50:51, :15,]
ppt51_dist =ppt51_dist.reshape(15,15)
ppt52_dist = data[51:52, :15,]
ppt52_dist =ppt52_dist.reshape(15,15)
ppt53_dist = data[52:53, :15,]
ppt53_dist =ppt53_dist.reshape(15,15)
ppt54_dist = data[53:54, :15,]
ppt54_dist =ppt44_dist.reshape(15,15)
ppt55_dist = data[54:55, :15,]
ppt55_dist =ppt45_dist.reshape(15,15)
ppt56_dist = data[55:56, :15,]
ppt56_dist =ppt46_dist.reshape(15,15)
ppt57_dist = data[56:57, :15,]
ppt57_dist =ppt47_dist.reshape(15,15)
ppt58_dist = data[57:58, :15,]
ppt58_dist =ppt48_dist.reshape(15,15)
ppt59_dist = data[58:59, :15,]
ppt59_dist =ppt49_dist.reshape(15,15)
ppt60_dist = data[59:60, :15,]
ppt60_dist =ppt60_dist.reshape(15,15)
ppt61_dist = data[60:61, :15,]
ppt61_dist =ppt61_dist.reshape(15,15)
ppt62_dist = data[61:62, :15,]
ppt62_dist =ppt62_dist.reshape(15,15)
ppt63_dist = data[62:63, :15,]
ppt63_dist =ppt63_dist.reshape(15,15)
ppt64_dist = data[63:64, :15,]
ppt64_dist =ppt64_dist.reshape(15,15)
ppt65_dist = data[64:65, :15,]
ppt65_dist =ppt65_dist.reshape(15,15)
ppt66_dist = data[65:66, :15,]
ppt66_dist =ppt66_dist.reshape(15,15)
ppt67_dist = data[66:67, :15,]
ppt67_dist =ppt67_dist.reshape(15,15)
ppt68_dist = data[67:68, :15,]
ppt68_dist =ppt68_dist.reshape(15,15)
ppt69_dist = data[68:69, :15,]
ppt69_dist =ppt69_dist.reshape(15,15)
ppt70_dist = data[69:70, :15,]
ppt70_dist =ppt70_dist.reshape(15,15)
ppt71_dist = data[70:71, :15,]
ppt71_dist =ppt71_dist.reshape(15,15)
ppt72_dist = data[71:72, :15,]
ppt72_dist =ppt72_dist.reshape(15,15)
ppt73_dist = data[72:73, :15,]
ppt73_dist =ppt73_dist.reshape(15,15)
ppt74_dist = data[73:74, :15,]
ppt74_dist =ppt74_dist.reshape(15,15)
ppt75_dist = data[74:75, :15,]
ppt75_dist =ppt75_dist.reshape(15,15)
ppt76_dist = data[75:76, :15,]
ppt76_dist =ppt76_dist.reshape(15,15)
ppt77_dist = data[76:77, :15,]
ppt77_dist =ppt77_dist.reshape(15,15)
ppt78_dist = data[77:78, :15,]
ppt78_dist =ppt78_dist.reshape(15,15)
ppt79_dist = data[78:79, :15,]
ppt79_dist =ppt79_dist.reshape(15,15)
ppt80_dist = data[79:80, :15,]
ppt80_dist =ppt80_dist.reshape(15,15)
ppt81_dist = data[80:81, :15,]
ppt81_dist =ppt81_dist.reshape(15,15)
ppt82_dist = data[81:82, :15,]
ppt82_dist =ppt82_dist.reshape(15,15)
ppt83_dist = data[82:83, :15,]
ppt83_dist =ppt83_dist.reshape(15,15)
ppt84_dist = data[83:84, :15,]
ppt84_dist =ppt84_dist.reshape(15,15)
ppt85_dist = data[84:85, :15,]
ppt85_dist =ppt85_dist.reshape(15,15)
ppt86_dist = data[85:86, :15,]
ppt86_dist =ppt86_dist.reshape(15,15)
ppt87_dist = data[86:87, :15,]
ppt87_dist =ppt87_dist.reshape(15,15)
ppt88_dist = data[87:88, :15,]
ppt88_dist =ppt88_dist.reshape(15,15)
ppt89_dist = data[88:89, :15,]
ppt89_dist =ppt89_dist.reshape(15,15)
ppt90_dist = data[89:90, :15,]
ppt90_dist =ppt90_dist.reshape(15,15)
ppt91_dist = data[90:91, :15,]
ppt91_dist =ppt91_dist.reshape(15,15)
ppt92_dist = data[91:92, :15,]
ppt92_dist =ppt92_dist.reshape(15,15)
ppt93_dist = data[92:93, :15,]
ppt93_dist =ppt93_dist.reshape(15,15)
ppt94_dist = data[93:94, :15,]
ppt94_dist =ppt94_dist.reshape(15,15)
ppt95_dist = data[94:95, :15,]
ppt95_dist =ppt95_dist.reshape(15,15)
ppt96_dist = data[95:96, :15,]
ppt96_dist =ppt96_dist.reshape(15,15)
ppt97_dist = data[96:97, :15,]
ppt97_dist =ppt97_dist.reshape(15,15)
ppt98_dist = data[97:98, :15,]
ppt98_dist =ppt98_dist.reshape(15,15)
ppt99_dist = data[98:99, :15,]
ppt99_dist =ppt99_dist.reshape(15,15)
ppt100_dist = data[99:100, :15,]
ppt100_dist =ppt100_dist.reshape(15,15)

# %% [markdown]
# Now that we've computed a dissimilarity matrix for all participants, we now want to plot the distances using multidimensional scaling...

# %%
#First need to take an average of the similarity score collapsing across the array
All_data = np.mean(data, axis=0)
All_data
# Out:
# array([[0.      , 2.347088, 6.006914, 4.340256, 7.314999, 0.554539,
#         3.176349, 1.511797, 4.351734, 0.665295, 5.895299, 0.606435,
#         3.373536, 3.872034, 6.768732],
#        [2.347088, 0.      , 2.051891, 1.521894, 1.508536, 4.905867,
#         1.074954, 3.856507, 1.789859, 5.761266, 1.531376, 5.472597,
#         0.89216 , 1.098779, 1.531319],
#        [6.006914, 2.051891, 0.      , 4.937487, 6.800087, 1.009022,
#         3.370381, 1.878088, 5.180734, 0.939066, 5.715626, 1.101413,
#         3.465703, 4.103633, 7.742553],
#        [4.340256, 1.521894, 4.937487, 0.      , 5.356918, 0.567343,
#         6.139061, 1.165138, 6.95283 , 0.445948, 5.433983, 0.487822,
#         6.313235, 6.768488, 5.662543],
#        [7.314999, 1.508536, 6.800087, 5.356918, 0.      , 0.428665,
#         3.439892, 1.757037, 4.442979, 0.380566, 7.079211, 0.409431,
#         3.532882, 4.677232, 7.360182],
#        [0.554539, 4.905867, 1.009022, 0.567343, 0.428665, 0.      ,
# ...

# %%
import numpy as np  
import scipy
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances #jaccard diss.
from sklearn import manifold  # multidimensional scaling

#Compute dissimilarity matrix
dis_matrix = pairwise_distances(All_data, metric = 'euclidean') #NEED TO DECIDE IF WE ARE DOING MANHATTAN OR EUCLIDEAN AND MAKE IT CONSISTENT
dis_matrix
# Out:
# array([[ 0.        , 14.61847307,  8.67774751,  8.8049968 , 10.58693344,
#         18.18144094,  9.37520348, 13.55091238,  8.55008587, 18.38557327,
#          8.80631854, 18.16351742,  9.51562194,  9.56953853, 10.0286672 ],
#        [14.61847307,  0.        , 14.54127566, 16.03249984, 15.57850453,
#          8.55523473, 14.47992136,  5.86366242, 15.29537687,  9.83533274,
#         15.03228273,  9.31290577, 14.98213294, 15.94979579, 16.02129194],
#        [ 8.67774751, 14.54127566,  0.        ,  9.25437971,  9.93453841,
#         18.57393283,  9.46337687, 14.05259077,  9.34631634, 18.64140454,
#          8.53761782, 18.60936092,  9.4105928 ,  9.5947316 , 11.1563921 ],
#        [ 8.8049968 , 16.03249984,  9.25437971,  0.        , 10.06821847,
#         19.9761073 ,  9.64039376, 15.44772461, 10.00197911, 20.04131107,
#          9.10323673, 19.87320095,  9.6344812 ,  9.90122416, 10.08608775],
#        [10.58693344, 15.57850453,  9.93453841, 10.06821847,  0.        ,
# ...

# %%
import numpy as np  
import scipy
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances 
from sklearn import manifold  # multidimensional scaling

mds_model = manifold.MDS(n_components = 2, random_state = 2021,
    dissimilarity = 'precomputed')

mds_fit = mds_model.fit(dis_matrix)  
mds_coords = mds_model.fit_transform(dis_matrix) 

mds_coords
# Out:
# array([[ -3.19106124,   0.69399779],
#        [  6.01394292,   6.14793641],
#        [ -5.66521301,   4.40098591],
#        [ -8.67880198,  -4.09983226],
#        [ -5.52600048,  -7.72455278],
#        [  6.66116694,  12.13932656],
#        [ -0.56422989,  -3.91289076],
#        [  7.59799987,   2.90224738],
#        [ -4.57713503,  -3.26481302],
#        [ 14.04955553,   0.4138361 ],
#        [ -7.14224682,   1.51894452],
#        [ 11.7784315 ,   7.28511239],
#        [  1.24125093,  -7.45237474],
#        [-10.13148295,   0.71615386],
#        [ -1.8661763 ,  -9.76407736]])

# %%
image_names = ['Animals_010', 'Animals_206', 'Faces_017', 'Faces_032', 'Faces_041', 'Faces_134', 'Faces_270', 'Faces_315', 'Landscapes_026', 'Landscapes_132', 'Objects_145', 'People_067', 'People_075', 'People_127', 'People_143']

### PLOT THE CO-ORDINATES ABOVE IN THE FIGURE
plt.figure()
plt.scatter(mds_coords[:,0],mds_coords[:,1],
    facecolors = 'black', edgecolors = 'black')  # points in black (change by saying 'blue', 'white', etc.)
#Add labels to each of the dots
labels = image_names
for label, x, y in zip(labels, mds_coords[:,0], mds_coords[:,1]):
    plt.annotate(label, (x,y), xycoords = 'data')

    #Add labels to the axes
plt.xlabel('First Dimension')
plt.ylabel('Second Dimension')
plt.title('Dissimilarity among images')    

plt.show()

# %% [markdown]
# Now we want to compute distances within clusters and between clusters for each participant

# %%
#Define what group the images are in
Angry = ['Animals_008_v.jpg','Faces_032_h.jpg', 'Faces_270_h.jpg', 'Faces_273_h.jpg', 'Landscapes_007_h.jpg', 'Landscapes_026_h.jpg', 'Landscapes_139_h.jpg', 'Objects_106_v.jpg', 'People_075_v.jpg', 'People_087_h.jpg', 'People_127_h.jpg']
Happy = ['Animals_206_h.jpg', 'Faces_134_h.jpg', 'Faces_315_h.jpg', 'Faces_318_v.jpg', 'Landscapes_075_h.jpg', 'Landscapes_119_h.jpg', 'Landscapes_132_h.jpg', 'People_067_h.jpg', 'Objects_319_h.jpg', 'People_068_h.jpg', 'People_089_h.jpg']
Sad = ['Animals_010_h.jpg', 'Faces_017_h.jpg', 'Faces_041_h.jpg', 'Faces_190_h.jpg', 'Landscapes_002_h.jpg', 'Landscapes_025_h.jpg', 'Landscapes_070_h.jpg', 'Objects_145_h.jpg', 'People_035_h.jpg', 'People_122_h.jpg', 'People_143_h.jpg']

# %%
#Make empty variables for within-cluster average and between-cluster average
All_within_cluster = []
All_between_cluster = []
All_total_distances = []


#Go through all of the dataframes in turn and do complete the following...
for i in [ppt1_dist,ppt2_dist,ppt3_dist, ppt4_dist, ppt5_dist, ppt6_dist, ppt7_dist, ppt8_dist, ppt9_dist, ppt10_dist, ppt11_dist, ppt12_dist, ppt13_dist, ppt14_dist, ppt15_dist, ppt16_dist, ppt17_dist, ppt18_dist, ppt19_dist, ppt20_dist, ppt21_dist, ppt22_dist, ppt23_dist, ppt24_dist, ppt25_dist, ppt26_dist, ppt27_dist, ppt28_dist, ppt29_dist, ppt30_dist, ppt31_dist, ppt32_dist, ppt33_dist, ppt34_dist, ppt35_dist, ppt36_dist, ppt37_dist, ppt38_dist, ppt39_dist, ppt40_dist, ppt41_dist, ppt42_dist, ppt43_dist, ppt44_dist, ppt45_dist, ppt46_dist, ppt47_dist, ppt48_dist, ppt49_dist, ppt50_dist, ppt51_dist, ppt52_dist, ppt53_dist, ppt54_dist, ppt55_dist, ppt56_dist, ppt57_dist, ppt58_dist, ppt59_dist, ppt60_dist, ppt61_dist, ppt62_dist, ppt63_dist, ppt64_dist, ppt65_dist, ppt66_dist, ppt67_dist, ppt68_dist, ppt69_dist, ppt70_dist, ppt71_dist, ppt72_dist, ppt73_dist, ppt74_dist, ppt75_dist, ppt76_dist, ppt77_dist, ppt78_dist, ppt79_dist, ppt80_dist, ppt81_dist, ppt82_dist, ppt83_dist, ppt84_dist, ppt85_dist, ppt86_dist, ppt87_dist, ppt88_dist, ppt89_dist, ppt90_dist, ppt91_dist, ppt92_dist, ppt93_dist, ppt94_dist, ppt95_dist, ppt96_dist, ppt97_dist, ppt98_dist, ppt99_dist, ppt100_dist]: 
    #Make a disimilarity matrix for every participant
    dis_matrix2 = pairwise_distances(i, metric = 'euclidean')
    #Calculate within-cluster score
    within_cluster_score = (dis_matrix2[0,2]+ dis_matrix2[0,4] + dis_matrix2[0,10] + dis_matrix2[0,14] +
                           dis_matrix2[1,5] + dis_matrix2[1,7] + dis_matrix2[1,9] + dis_matrix2[1,11] +
                           dis_matrix2[2,4] + dis_matrix2[2,10] + dis_matrix2[2,14] +
                           dis_matrix2[3,6] + dis_matrix2[3,8] + dis_matrix2[3,12] + dis_matrix2[3,13] +
                           dis_matrix2[4,10] + dis_matrix2[4,14] +
                           dis_matrix2[5,7] + dis_matrix2[5,9] + dis_matrix2[5,11] +
                           dis_matrix2[6,8] + dis_matrix2[6,12] + dis_matrix2[6,13] +
                           dis_matrix2[7,9] + dis_matrix2[7,11] +
                           dis_matrix2[8,12] + dis_matrix2[8,13] +
                           dis_matrix2[9,11] +
                           dis_matrix[10,14] +
                           dis_matrix[12,13])
    
    within_cluster_average = within_cluster_score/30 #There are 30 combinations
    #Now compute between clusters
    Total_distances = np.sum(dis_matrix2)
    # Since the numbers are duplicated on the top and bottom of the matrix we need to divide by 2
    Total_distances = Total_distances/2
    Total_distances_average = Total_distances/105
    # Now subtract the within_cluster_score from the total distances score
    between_cluster_score = Total_distances - within_cluster_score
    #Now calculate the average for between cluster for this ppt
    # We divide by 75 because there are 105 total combinations and 30 of these are within-cluster
    between_cluster_average = between_cluster_score/75
    #Save this information into a dataframe
    All_total_distances.append(Total_distances_average)
    All_within_cluster.append(within_cluster_average)
    All_between_cluster.append(between_cluster_average)
    #Make all variables 0 before going to the next loop
    within_cluster_average = 0
    between_cluster_average = 0

# %%
#Join together the dataframes 
All_cluster_averages = pd.DataFrame(
    {'Participant ID' : participants,
     'Total_Distance average': All_total_distances,
     'Within_cluster': All_within_cluster,
     'Between_cluster': All_between_cluster,
    })

All_cluster_averages
# Out:
#        Participant ID  Total_Distance average  Within_cluster  Between_cluster
# 0   R_0Dp0iH4GOukII4F               22.114003       17.274445        24.049826
# 1   R_0VP8Pj9Gdco2iFb               14.123918       11.515874        15.167136
# 2   R_10Tb9qR3qjOJWbQ               15.481239       12.706412        16.591169
# 3   R_10vFnrM7bdX5Tv4               20.163684       14.957245        22.246260
# 4   R_1CJElctSLBwFItB               15.547121       11.866448        17.019391
# ..                ...                     ...             ...              ...
# 95  R_XoYnrATnuo93j2N               24.302105       17.946392        26.844390
# 96  R_xsXqyqj1J7woCIh               19.327091       15.403258        20.896625
# 97  R_yrRpfmg41NNLRkd               14.206170       12.350682        14.948365
# 98  R_zbSh8kB93TjcAMh               15.933444       13.154392        17.045065
# 99  R_Zjz85jGQ12UKMzD               21.590635       17.907620        23.063841
#
# [100 rows x 4 columns]

# %%
import csv

# open the file in the write mode
f = open('Documents/All Cluster Averages.csv', 'w')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow(All_cluster_averages)

# close the file
f.close()

# %%
All_cluster_averages.to_csv('Documents/All Cluster Averages_euclidean.csv', sep='\t')

# %% [markdown]
# Now calculate the within-cluster distances for each emotion for all the participants

# %%
All_Angry_Cluster = []
All_Happy_Cluster = []
All_Sad_Cluster = []

#Go through all of the dataframes in turn and do complete the following...
for i in [ppt1_dist,ppt2_dist,ppt3_dist, ppt4_dist, ppt5_dist, ppt6_dist, ppt7_dist, ppt8_dist, ppt9_dist, ppt10_dist, ppt11_dist, ppt12_dist, ppt13_dist, ppt14_dist, ppt15_dist, ppt16_dist, ppt17_dist, ppt18_dist, ppt19_dist, ppt20_dist, ppt21_dist, ppt22_dist, ppt23_dist, ppt24_dist, ppt25_dist, ppt26_dist, ppt27_dist, ppt28_dist, ppt29_dist, ppt30_dist, ppt31_dist, ppt32_dist, ppt33_dist, ppt34_dist, ppt35_dist, ppt36_dist, ppt37_dist, ppt38_dist, ppt39_dist, ppt40_dist, ppt41_dist, ppt42_dist, ppt43_dist, ppt44_dist, ppt45_dist, ppt46_dist, ppt47_dist, ppt48_dist, ppt49_dist, ppt50_dist, ppt51_dist, ppt52_dist, ppt53_dist, ppt54_dist, ppt55_dist, ppt56_dist, ppt57_dist, ppt58_dist, ppt59_dist, ppt60_dist, ppt61_dist, ppt62_dist, ppt63_dist, ppt64_dist, ppt65_dist, ppt66_dist, ppt67_dist, ppt68_dist, ppt69_dist, ppt70_dist, ppt71_dist, ppt72_dist, ppt73_dist, ppt74_dist, ppt75_dist, ppt76_dist, ppt77_dist, ppt78_dist, ppt79_dist, ppt80_dist, ppt81_dist, ppt82_dist, ppt83_dist, ppt84_dist, ppt85_dist, ppt86_dist, ppt87_dist, ppt88_dist, ppt89_dist, ppt90_dist, ppt91_dist, ppt92_dist, ppt93_dist, ppt94_dist, ppt95_dist, ppt96_dist, ppt97_dist, ppt98_dist, ppt99_dist, ppt100_dist]:  
    #Make a disimilarity matrix for every participant
    dis_matrix = pairwise_distances(i, metric = 'euclidean')
    #Calculate within-cluster score
    Angry_cluster_score = (dis_matrix[3,6] + dis_matrix[3,8] + dis_matrix[3,12] + dis_matrix[3,13] + dis_matrix[6,8] + dis_matrix[6,12] + dis_matrix[6,13] + dis_matrix[8,12] + dis_matrix[8,13] + dis_matrix[12,13])
    Happy_cluster_score = (dis_matrix[1,5] + dis_matrix[1,7] + dis_matrix[1,9] + dis_matrix[1,11] + dis_matrix[5,7] + dis_matrix[5,9] + dis_matrix[5,11] + dis_matrix[7,9] + dis_matrix[7,11] + dis_matrix[9,11])
    Sad_cluster_score = (dis_matrix[0,2]+ dis_matrix[0,4] + dis_matrix[0,10] + dis_matrix[0,14] + dis_matrix[2,4] + dis_matrix[2,10] + dis_matrix[2,14] + dis_matrix[4,10] + dis_matrix[4,14] + dis_matrix[10,14])
    #Calculate average distance between images for each emotion
    Angry_cluster_average = Angry_cluster_score/10 #There are 10 combinations
    Happy_cluster_average = Happy_cluster_score/10 #There are 10 combinations
    Sad_cluster_average = Sad_cluster_score/10 #There are 10 combinations
    #Save this information into a dataframe
    All_Angry_Cluster.append(Angry_cluster_average)
    All_Happy_Cluster.append(Happy_cluster_average)
    All_Sad_Cluster.append(Sad_cluster_average)
    #Make all variables 0 before going to the next loop
    Angry_cluster_average = 0
    Happy_cluster_average = 0
    Sad_cluster_average = 0

# %%
AHS_cluster_averages = pd.DataFrame(
    {'Participant ID' : participants,
     'Angry_cluster': All_Angry_Cluster,
     'Happy_cluster': All_Happy_Cluster,
     'Sad_cluster' : All_Sad_Cluster
    })

AHS_cluster_averages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e62a5d863c56> in <module>
# ----> 1 AHS_cluster_averages = pd.DataFrame(
#       2     {'Participant ID' : participants,
#       3      'Angry_cluster': All_Angry_Cluster,
#       4      'Happy_cluster': All_Happy_Cluster,
#       5      'Sad_cluster' : All_Sad_Cluster
#
# NameError: name 'pd' is not defined

# %%
AHS_cluster_averages.to_csv('Documents/AHS Cluster Averages_euclidean.csv', sep='\t')

# %% [markdown]
# Now compute between cluster distances for angry-happy, angry-sad and happy-sad respectively

# %%
All_Angry_Happy = []
All_Angry_Sad = []
All_Happy_Sad = []

#Go through all of the dataframes in turn and do complete the following...
for i in [ppt1_dist,ppt2_dist,ppt3_dist, ppt4_dist, ppt5_dist, ppt6_dist, ppt7_dist, ppt8_dist, ppt9_dist, ppt10_dist, ppt11_dist, ppt12_dist, ppt13_dist, ppt14_dist, ppt15_dist, ppt16_dist, ppt17_dist, ppt18_dist, ppt19_dist, ppt20_dist, ppt21_dist, ppt22_dist, ppt23_dist, ppt24_dist, ppt25_dist, ppt26_dist, ppt27_dist, ppt28_dist, ppt29_dist, ppt30_dist, ppt31_dist, ppt32_dist, ppt33_dist, ppt34_dist, ppt35_dist, ppt36_dist, ppt37_dist, ppt38_dist, ppt39_dist, ppt40_dist, ppt41_dist, ppt42_dist, ppt43_dist, ppt44_dist, ppt45_dist, ppt46_dist, ppt47_dist, ppt48_dist, ppt49_dist, ppt50_dist, ppt51_dist, ppt52_dist, ppt53_dist, ppt54_dist, ppt55_dist, ppt56_dist, ppt57_dist, ppt58_dist, ppt59_dist, ppt60_dist, ppt61_dist, ppt62_dist, ppt63_dist, ppt64_dist, ppt65_dist, ppt66_dist, ppt67_dist, ppt68_dist, ppt69_dist, ppt70_dist, ppt71_dist, ppt72_dist, ppt73_dist, ppt74_dist, ppt75_dist, ppt76_dist, ppt77_dist, ppt78_dist, ppt79_dist, ppt80_dist, ppt81_dist, ppt82_dist, ppt83_dist, ppt84_dist, ppt85_dist, ppt86_dist, ppt87_dist, ppt88_dist, ppt89_dist, ppt90_dist, ppt91_dist, ppt92_dist, ppt93_dist, ppt94_dist, ppt95_dist, ppt96_dist, ppt97_dist, ppt98_dist, ppt99_dist, ppt100_dist]:  
    #Make a disimilarity matrix for every participant
    dis_matrix = pairwise_distances(i, metric = 'euclidean')
    #Calculate within-cluster score
    Angry_Happy_dist_score = (dis_matrix[3,5] + dis_matrix[3,7] + dis_matrix[3,9] + dis_matrix[3,11] + dis_matrix[6,7] + dis_matrix[6,9] + dis_matrix[6,11] + dis_matrix[8,9] + dis_matrix[8,11] + dis_matrix[1,3] + dis_matrix[1,6] + dis_matrix[1,8] + dis_matrix[1,12] + dis_matrix[1,13] + dis_matrix[5,6] + dis_matrix[5,8] + dis_matrix[5,12] + dis_matrix[5,13] + dis_matrix[7,8] + dis_matrix[7,12] + dis_matrix[7,13] + dis_matrix[9,12] + dis_matrix[9,13] + dis_matrix[11,12] + dis_matrix[11,13])
    Angry_Sad_dist_score = (dis_matrix[0,3] + dis_matrix[0,6] + dis_matrix[0,8] + dis_matrix[0,12] + dis_matrix[0,13] + dis_matrix[2,3] + dis_matrix[2,6] + dis_matrix[2,8] + dis_matrix[2,12] + dis_matrix[2,13] + dis_matrix[4,6] + dis_matrix[4,8] + dis_matrix[4,12] + dis_matrix[4,13] + dis_matrix[10,12] + dis_matrix[10,13] + dis_matrix[3,4] + dis_matrix[3,10] + dis_matrix[3,14] + dis_matrix[6,10] + dis_matrix[6,14] + dis_matrix[8,10] + dis_matrix[8,14] + dis_matrix[12,14] + dis_matrix[13,14])
    Happy_Sad_dist_score = (dis_matrix[0,1] + dis_matrix[0,5] + dis_matrix[0,7] + dis_matrix[0,9] + dis_matrix[0,11] + dis_matrix[2,5] + dis_matrix[2,7] + dis_matrix[2,9] + dis_matrix[2,11] + + dis_matrix[4,5] + dis_matrix[4,7] + dis_matrix[4,9] + dis_matrix[4,11] + dis_matrix[10,11] + dis_matrix[1,2] + dis_matrix[1,4] + dis_matrix[1,10] + dis_matrix[1,14] + dis_matrix[5,10] + dis_matrix[5,14] + dis_matrix[7,10] + dis_matrix[7,14] + dis_matrix[9,10] + dis_matrix[9,14] + dis_matrix[11,14])
    #Calculate average distance between images for each emotion
    Angry_Happy_dist_average = Angry_Happy_dist_score/25 #There are 25 combinations
    Angry_Sad_dist_average = Angry_Sad_dist_score/25 #There are 25 combinations
    Happy_Sad_dist_average = Happy_Sad_dist_score/25 #There are 25 combinations
    #Save this information into a dataframe
    All_Angry_Happy.append(Angry_Happy_dist_average)
    All_Angry_Sad.append(Angry_Sad_dist_average)
    All_Happy_Sad.append(Happy_Sad_dist_average)
    #Make all variables 0 before going to the next loop
    Angry_Happy_dist_average = 0
    Angry_Sad_dist_average = 0
    Happy_Sad_dist_average = 0

# %%
AHS_distance_averages = pd.DataFrame(
    {'Participant ID' : participants,
     'Dist_Angry_Happy': All_Angry_Happy,
     'Dist_Angry_Sad': All_Angry_Sad,
     'Dist_Happy_Sad' : All_Happy_Sad
    })

AHS_distance_averages
# Out:
#        Participant ID  Dist_Angry_Happy  Dist_Angry_Sad  Dist_Happy_Sad
# 0   R_0Dp0iH4GOukII4F         26.472713       18.024711       26.767490
# 1   R_0VP8Pj9Gdco2iFb         17.214379       11.411180       16.773334
# 2   R_10Tb9qR3qjOJWbQ         15.335757       15.572779       18.462810
# 3   R_10vFnrM7bdX5Tv4         21.057457       20.727867       24.463898
# 4   R_1CJElctSLBwFItB         21.012448       10.427920       19.530567
# ..                ...               ...             ...             ...
# 95  R_XoYnrATnuo93j2N         31.341678       20.109314       28.305168
# 96  R_xsXqyqj1J7woCIh         22.861877       16.105565       23.125276
# 97  R_yrRpfmg41NNLRkd         15.570513       11.612497       17.624582
# 98  R_zbSh8kB93TjcAMh         19.663034       12.894562       18.423527
# 99  R_Zjz85jGQ12UKMzD         24.482469       18.338399       25.784806
#
# [100 rows x 4 columns]

# %%
AHS_distance_averages.to_csv('Documents/AHS Distance Averages_euclidean.csv', sep='\t')
